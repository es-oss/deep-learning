# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers

# %%
data = '/content/gdrive/MyDrive/data/seg_train'

# %%
data_train = tf.keras.utils.image_dataset_from_directory(
    data_train_path,
    shuffle=True,
    image_size=(img_width, img_height),
    batch_size=32,
    validation_split=False)
# Out:
# Found 3115 files belonging to 36 classes.

# %%
data_cat = data_train.class_names

# %%
data_cat
# Out:
# ['apple',
#  'banana',
#  'beetroot',
#  'bell pepper',
#  'cabbage',
#  'capsicum',
#  'carrot',
#  'cauliflower',
#  'chilli pepper',
#  'corn',
#  'cucumber',
#  'eggplant',
#  'garlic',
#  'ginger',
#  'grapes',
#  'jalepeno',
#  'kiwi',
#  'lemon',
#  'lettuce',
#  'mango',
#  'onion',
#  'orange',
#  'paprika',
#  'pear',
#  'peas',
#  'pineapple',
#  'pomegranate',
#  'potato',
#  'raddish',
#  'soy beans',
#  'spinach',
#  'sweetcorn',
#  'sweetpotato',
#  'tomato',
#  'turnip',
#  'watermelon']

# %%
data_val = tf.keras.utils.image_dataset_from_directory(data_val_path,
                                                       image_size=(img_height,img_width),
                                                       batch_size=32,
                                                        shuffle=False,
                                                       validation_split=False)
# Out:
# Found 351 files belonging to 36 classes.

# %%
data_test = tf.keras.utils.image_dataset_from_directory(
data_test_path,
    image_size=(img_height,img_width),
    shuffle=False,
    batch_size=32,
    validation_split=False
)
# Out:
# Found 359 files belonging to 36 classes.

# %%
plt.figure(figsize=(10,10))
for image, labels in data_train.take(1):
    for i in range(9):
        plt.subplot(3,3,i+1)
        plt.imshow(image[i].numpy().astype('uint8'))
        plt.title(data_cat[labels[i]])
        plt.axis('off')

# %%
from tensorflow.keras.models import Sequential

# %%
data_train
# Out:
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 180, 180, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
model = Sequential([
    layers.Rescaling(1./255),
    layers.Conv2D(16, 3, padding='same', activation='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(32,3, padding='same',activation='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(64, 3, padding='same', activation='relu'),
    layers.MaxPooling2D(),
    layers.Flatten(),
    layers.Dropout(0.2),
    layers.Dense(128),
    layers.Dense(len(data_cat))

])

# %%
model.compile(optimizer='adam', loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True), metrics=['accuracy'])

# %%
epochs_size = 25
history = model.fit(data_train, validation_data=data_val, epochs=epochs_size)
# Out:
# Epoch 1/25
# 98/98 [==============================] - 808s 8s/step - loss: 3.4146 - accuracy: 0.0934 - val_loss: 2.4323 - val_accuracy: 0.3191
# Epoch 2/25
# 98/98 [==============================] - 75s 715ms/step - loss: 2.4497 - accuracy: 0.3079 - val_loss: 1.5626 - val_accuracy: 0.5755
# Epoch 3/25
# 98/98 [==============================] - 75s 710ms/step - loss: 1.8183 - accuracy: 0.4668 - val_loss: 0.9741 - val_accuracy: 0.7635
# Epoch 4/25
# 98/98 [==============================] - 75s 717ms/step - loss: 1.1693 - accuracy: 0.6616 - val_loss: 0.5950 - val_accuracy: 0.8604
# Epoch 5/25
# 98/98 [==============================] - 76s 720ms/step - loss: 0.6982 - accuracy: 0.8087 - val_loss: 0.4516 - val_accuracy: 0.9031
# Epoch 6/25
# 98/98 [==============================] - 76s 734ms/step - loss: 0.4135 - accuracy: 0.8934 - val_loss: 0.3833 - val_accuracy: 0.9231
# Epoch 7/25
# 98/98 [==============================] - 75s 719ms/step - loss: 0.2781 - accuracy: 0.9271 - val_loss: 0.4235 - val_accuracy: 0.9487
# Epoch 8/25
# 98/98 [==============================] - 76s 719ms/step - loss: 0.2012 - accuracy: 0.9547 - val_loss: 0.3843 - val_accuracy: 0.9430
# Epoch 9/25
# 98/98 [==============================] - 75s 727ms/step - loss: 0.1902 - accuracy: 0.9551 - val_loss: 0.3942 - val_accuracy: 0.9345
# Epoch 10/25
# 98/98 [==============================] - 73s 707ms/step - loss: 0.1498 - accuracy: 0.9695 - val_loss: 0.4202 - val_accuracy: 0.9544
# Epoch 11/25
# 98/98 [==============================] - 75s 712ms/step - loss: 0.1279 - accuracy: 0.9769 - val_loss: 0.3104 - val_accuracy: 0.9601
# Epoch 12/25
# 98/98 [==============================] - 75s 723ms/step - loss: 0.1026 - accuracy: 0.9801 - val_loss: 0.3905 - val_accuracy: 0.9516
# Epoch 13/25
# 98/98 [==============================] - 74s 712ms/step - loss: 0.1158 - accuracy: 0.9746 - val_loss: 0.4483 - val_accuracy: 0.9430
# Epoch 14/25
# 98/98 [==============================] - 75s 722ms/step - loss: 0.1158 - accuracy: 0.9772 - val_loss: 0.3836 - val_accuracy: 0.9516
# Epoch 15/25
# 98/98 [==============================] - 74s 709ms/step - loss: 0.0878 - accuracy: 0.9827 - val_loss: 0.2979 - val_accuracy: 0.9573
# Epoch 16/25
# 98/98 [==============================] - 74s 716ms/step - loss: 0.0695 - accuracy: 0.9872 - val_loss: 0.3177 - val_accuracy: 0.9573
# Epoch 17/25
# 98/98 [==============================] - 75s 707ms/step - loss: 0.0611 - accuracy: 0.9894 - val_loss: 0.3106 - val_accuracy: 0.9601
# Epoch 18/25
# 98/98 [==============================] - 75s 722ms/step - loss: 0.0632 - accuracy: 0.9875 - val_loss: 0.2673 - val_accuracy: 0.9630
# Epoch 19/25
# 98/98 [==============================] - 74s 704ms/step - loss: 0.0650 - accuracy: 0.9862 - val_loss: 0.3382 - val_accuracy: 0.9516
# Epoch 20/25
# 98/98 [==============================] - 73s 706ms/step - loss: 0.0605 - accuracy: 0.9878 - val_loss: 0.3740 - val_accuracy: 0.9573
# Epoch 21/25
# 98/98 [==============================] - 74s 705ms/step - loss: 0.0498 - accuracy: 0.9904 - val_loss: 0.3663 - val_accuracy: 0.9573
# Epoch 22/25
# 98/98 [==============================] - 75s 725ms/step - loss: 0.0672 - accuracy: 0.9852 - val_loss: 0.3530 - val_accuracy: 0.9573
# Epoch 23/25
# 98/98 [==============================] - 74s 704ms/step - loss: 0.0556 - accuracy: 0.9836 - val_loss: 0.3724 - val_accuracy: 0.9516
# Epoch 24/25
# 98/98 [==============================] - 75s 708ms/step - loss: 0.0648 - accuracy: 0.9817 - val_loss: 0.3283 - val_accuracy: 0.9544
# Epoch 25/25
# 98/98 [==============================] - 75s 723ms/step - loss: 0.0898 - accuracy: 0.9769 - val_loss: 0.5639 - val_accuracy: 0.9373

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
epochs_range = range(epochs_size)
plt.figure(figsize=(8,8))
plt.subplot(1,2,1)
plt.plot(epochs_range,history.history['accuracy'],label = 'Training Accuracy')
plt.plot(epochs_range, history.history['val_accuracy'],label = 'Validation Accuracy')
plt.title('Accuracy')

plt.subplot(1,2,2)
plt.plot(epochs_range,history.history['loss'],label = 'Training Loss')
plt.plot(epochs_range, history.history['val_loss'],label = 'Validation Loss')
plt.title('Loss')
# Out:
# Text(0.5, 1.0, 'Loss')

# %%
image = 'corn.jpg'
image = tf.keras.utils.load_img(image, target_size=(img_height,img_width))
img_arr = tf.keras.utils.array_to_img(image)
img_bat=tf.expand_dims(img_arr,0)

# %%
predict = model.predict(img_bat)
# Out:
# 1/1 [==============================] - 0s 310ms/step

# %%
score = tf.nn.softmax(predict)

# %%
print('Veg/Fruit in image is {} with accuracy of {:0.2f}'.format(data_cat[np.argmax(score)],np.max(score)*100))
# Out:
# Veg/Fruit in image is corn with accuracy of 70.34

# %%
model.save('Image_classify.keras')
